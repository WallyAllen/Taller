# %%
rounds = [
{
'theme': 'Entrada',
'scores': {
'Valentina': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Mateo': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
'Camila': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Santiago': {'judge_1': 6, 'judge_2': 7,
'judge_3': 6},
'Lucía': {'judge_1': 8, 'judge_2': 8,
'judge_3': 8},
}
},
{
'theme': 'Plato principal',
'scores': {
'Valentina': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Mateo': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Camila': {'judge_1': 7, 'judge_2': 6,
'judge_3': 7},
'Santiago': {'judge_1': 9, 'judge_2': 8,
'judge_3': 8},
'Lucía': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
}
},
{
'theme': 'Postre',
'scores': {
'Valentina': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
'Mateo': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Camila': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Santiago': {'judge_1': 7, 'judge_2': 7,
'judge_3': 6},
'Lucía': {'judge_1': 9, 'judge_2': 9,
'judge_3': 9},
}
},
{
'theme': 'Cocina internacional',
'scores': {
'Valentina': {'judge_1': 8, 'judge_2': 9,
'judge_3': 9},
'Mateo': {'judge_1': 7, 'judge_2': 6,
'judge_3': 7},
'Camila': {'judge_1': 9, 'judge_2': 8,
'judge_3': 8},
'Santiago': {'judge_1': 8, 'judge_2': 9,
'judge_3': 7},
'Lucía': {'judge_1': 7, 'judge_2': 7,
'judge_3': 8},
}
},
{
'theme': 'Final libre',
'scores': {
'Valentina': {'judge_1': 9, 'judge_2': 8,
'judge_3': 9},
'Mateo': {'judge_1': 8, 'judge_2': 9,
'judge_3': 8},
'Camila': {'judge_1': 7, 'judge_2': 7,
'judge_3': 7},
'Santiago': {'judge_1': 9, 'judge_2': 9,
'judge_3': 9},
'Lucía': {'judge_1': 8, 'judge_2': 8,
'judge_3': 7},
}
}
]

# %%
puntaje_jugadores={}
puntajes= {}
for ronda in rounds:
    notas= {} #es un diccionario temporal, para guardar la nota del participante actual
    puntajes = ronda["scores"]
    for participante in puntajes: #de esta forma accedo a cada participante. Llame participantes por comodidad.
        nota= 0
        jueces = puntajes[participante] 
        for juez in jueces: #con esto accedo a cada puntaje de los jueces. Llame jueces por comodidad x2
            nota+= jueces[juez] #variable acumuladora
            notas[participante]= nota
        print(f"{participante} tiene una nota de: ", notas[participante])
        if participante in puntaje_jugadores:
            puntaje_jugadores[participante]["nota total"]+= nota #acumulacion
        else:
            puntaje_jugadores[participante]= {"nota total": nota} #seteo por primera vez
# Out:
# Valentina tiene una nota de:  24
# Mateo tiene una nota de:  22
# Camila tiene una nota de:  26
# Santiago tiene una nota de:  19
# Lucía tiene una nota de:  24
# Valentina tiene una nota de:  26
# Mateo tiene una nota de:  24
# Camila tiene una nota de:  20
# Santiago tiene una nota de:  25
# Lucía tiene una nota de:  22
# Valentina tiene una nota de:  22
# Mateo tiene una nota de:  26
# Camila tiene una nota de:  24
# Santiago tiene una nota de:  20
# Lucía tiene una nota de:  27
# Valentina tiene una nota de:  26
# Mateo tiene una nota de:  20
# Camila tiene una nota de:  25
# Santiago tiene una nota de:  24
# Lucía tiene una nota de:  22
# Valentina tiene una nota de:  26
# Mateo tiene una nota de:  25
# Camila tiene una nota de:  21
# Santiago tiene una nota de:  27
# Lucía tiene una nota de:  23

# %%
for ronda in rounds:
    puntajes = ronda["scores"]
    notamax= -1
    for participante in puntajes:
        nota= 0
        jueces = puntajes[participante]
        for juez in jueces:
           nota+= jueces[juez]
        if nota > notamax:
            notamax= nota
        if participante in puntaje_jugadores:
            actual= puntaje_jugadores[participante]
            if "nota mas alta" in actual: #verifico si existe la clave "nota mas alta" o si lo tengo que definir por primera vez
                if nota > actual["nota mas alta"]:
                    actual["nota mas alta"]= nota
            else:
                 actual["nota mas alta"]= nota       #siento que todos estos if los pude haber hecho de mejor manera. No esta muy limpio
        else:
            puntaje_jugadores[participante] = {"nota mas alta": nota} 
            
print(puntaje_jugadores)
# Out:
# {'Valentina': {'nota total': 124, 'nota mas alta': 26}, 'Mateo': {'nota total': 117, 'nota mas alta': 26}, 'Camila': {'nota total': 116, 'nota mas alta': 26}, 'Santiago': {'nota total': 115, 'nota mas alta': 27}, 'Lucía': {'nota total': 118, 'nota mas alta': 27}}

# %%
for ronda in rounds:
    puntajes = ronda["scores"]
    notamax= -1
    for participante in puntajes:
        nota= 0
        jueces = puntajes[participante] 
        for juez in jueces:
            nota+= jueces[juez]
        if nota > notamax:
            notamax= nota 
            participanteGanador= participante #variable identificadora
    if participanteGanador in puntaje_jugadores:
        actual = puntaje_jugadores[participanteGanador] 
        if "rondas Ganadas" in actual: #este if me permite hacer += solo cuando el campo de "rondas Ganadas" ya tenga un valor 
            actual["rondas Ganadas"] += 1 
        else:
            actual["rondas Ganadas"]= 1 
    else:
        puntaje_jugadores[participanteGanador]= {"rondas Ganadas": 1}  # creo que, como en el ejercicio anterior, hay cosas a mejorar. Este else ya cumpliria la funcion del if/else que comente 5 lineas arriba

print(puntaje_jugadores)
# Out:
# {'Valentina': {'nota total': 124, 'nota mas alta': 26, 'rondas Ganadas': 2}, 'Mateo': {'nota total': 117, 'nota mas alta': 26}, 'Camila': {'nota total': 116, 'nota mas alta': 26, 'rondas Ganadas': 1}, 'Santiago': {'nota total': 115, 'nota mas alta': 27, 'rondas Ganadas': 1}, 'Lucía': {'nota total': 118, 'nota mas alta': 27, 'rondas Ganadas': 1}}
